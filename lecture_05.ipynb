# %% [markdown]
# **Document Loaders in LangChain**

# %% [markdown]
# **Writing Document In Standard Form**
#
# documents come in many different shapes — a PDF, a Word file, a webpage, a CSV, etc. But your RAG pipeline doesn't understand all these formats directly. So you need to bring everything into one common, simple format that the system can work with.
#
# Raw File (PDF, URL, DOCX...)
#         ↓
#    Document Loader
#         ↓
#   Standard Document Object  ← "Standard Form"
#   { page_content, metadata }
#         ↓
#    Split → Embed → Store in Vector DB

# %%
# %pip install langchain langchain-community pypdf beautifulsoup4 lxml

# %%
from langchain_core.documents import Document
sample_document = Document(
    page_content = "This is the sample page content.",
    metadata ={"source":"Yar",
               "page":0,}
)

print(f"Content Of the File:{sample_document.page_content}")
print(f"metadata of the file:{sample_document.metadata}")
print(f"type of document:{type(sample_document)}")
# Out:
# Content Of the File:This is the sample page content.
# metadata of the file:{'source': 'Yar', 'page': 0}
# type of document:<class 'langchain_core.documents.base.Document'>

# %%
#To individually Access the each metadata
source = sample_document.metadata.get("source","unknown")
print(f"{source}")
# Out:
# Yar

# %% [markdown]
# **Txt DOcument Loader**
#
# Simple documnet loader or raw form document loader,This loader consider the all pages as one document or 1 page cannot differentiate or recongize pages.

# %%
from langchain_community.document_loaders import TextLoader
txt_file = TextLoader(
    file_path = "lang_practice.txt",
    encoding ="utf-8"
)

load_txt = txt_file.load()

print(f"Length of file is:{len(load_txt)}")
print(f"Page content is:{load_txt[0].page_content}")
print(f"metadata is:{load_txt[0].metadata}")
# Out:
# Length of file is:1
# Page content is:This document is about the nothing but just for langchainpractice.
# metadata is:{'source': 'lang_practice.txt'}

# %% [markdown]
# **PDF Loader**

# %%
from langchain_community.document_loaders import PyPDFLoader
pdf_file = PyPDFLoader(
    file_path = "lang_pdf.pdf",
)

pdf_file_load = pdf_file.load()

for index,page in enumerate(pdf_file_load[:3]):
    print(f"Page index:{index+1}")
    print(f"Page content:{page.page_content[:200]}")
# Out:
# invalid pdf header: b'This '
# EOF marker not found
# ---------------------------------------------------------------------------
# PdfStreamError                            Traceback (most recent call last)
# Cell In[6], line 6
#       1 from langchain_community.document_loaders import PyPDFLoader
#       2 pdf_file = PyPDFLoader(
#       3     file_path = "lang_pdf.pdf",
#       4 )
# ----> 6 pdf_file_load = pdf_file.load()
#       8 for index,page in enumerate(pdf_file_load[:3]):
#       9     print(f"Page index:{index+1}")
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\langchain_community\document_loaders\pdf.py:305, in PyPDFLoader.lazy_load(self)
#     303 else:
#     304     blob = Blob.from_path(self.file_path)
# --> 305 yield from self.parser.lazy_parse(blob)
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:384, in PyPDFParser.lazy_parse(self, blob)
#     378         return page.extract_text(
#     379             extraction_mode=self.extraction_mode,
#     380             **self.extraction_kwargs,
#     381         )
#     383 with blob.as_bytes_io() as pdf_file_obj:
# --> 384     pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
#     386     doc_metadata = _purge_metadata(
#     387         {"producer": "PyPDF", "creator": "PyPDF", "creationdate": ""}
#     388         | cast(dict, pdf_reader.metadata or {})
#    (...)
#     392         }
#     393     )
#     394     single_texts = []
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\pypdf\_reader.py:149, in PdfReader.__init__(self, stream, strict, password, root_object_recovery_limit)
#     145 self._page_id2num: Optional[dict[Any, Any]] = None
#     147 self._validated_root: Optional[DictionaryObject] = None
# --> 149 self._initialize_stream(stream)
#     150 self._known_objects: set[tuple[int, int]] = set()
#     152 self._override_encryption = False
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\pypdf\_reader.py:171, in PdfReader._initialize_stream(self, stream)
#     169         stream = BytesIO(fh.read())
#     170     self._stream_opened = True
# --> 171 self.read(stream)
#     172 self.stream = stream
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\pypdf\_reader.py:661, in PdfReader.read(self, stream)
#     653 """
#     654 Read and process the PDF stream, extracting necessary data.
#     655
#    (...)
#     658
#     659 """
#     660 self._basic_validation(stream)
# --> 661 self._find_eof_marker(stream)
#     662 startxref = self._find_startxref_pos(stream)
#     663 self._startxref = startxref
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\pypdf\_reader.py:767, in PdfReader._find_eof_marker(self, stream)
#     765         raise PdfReadError("EOF marker not found")
#     766     logger_warning("EOF marker not found", __name__)
# --> 767 line = read_previous_line(stream)
#
# File ~\PycharmProjects\darazscraper\.venv\lib\site-packages\pypdf\_utils.py:330, in read_previous_line(stream)
#     328 found_crlf = False
#     329 if stream.tell() == 0:
# --> 330     raise PdfStreamError(STREAM_TRUNCATED_PREMATURELY)
#     331 while True:
#     332     to_read = min(DEFAULT_BUFFER_SIZE, stream.tell())
#
# PdfStreamError: Stream has ended unexpectedly

# %% [markdown]
# **CSV Loaders**
#
# Every row is considered a page.

# %%
from langchain_community.document_loaders import CSVLoader
csv_file = CSVLoader(
    file_path = "lang_csv.csv",
)
csv_file_load = csv_file.load()

for index,doc in enumerate(csv_file_load):
    print(f"Document index:{index+1}")
    print(f"Content Of each row as as a single page:{doc.page_content}")
    print(f"The metadat is:{doc.metada}")
