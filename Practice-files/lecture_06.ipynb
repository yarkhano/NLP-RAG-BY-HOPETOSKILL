# %% [markdown]
# **Text Splitter or Chunkers**

# %%
from langchain_community.document_loaders import TextLoader
txt_loader = TextLoader(
    file_path = "yar.txt"
)

txt_file = txt_loader.load()

content = txt_file[0].page_content

print(f"length of content: {len(content)}")

#Tokens that this file have
print(f"The estimated tokens are:{len(content)//4}")

#first 20 characters of the file are
print(f"first 300 characters of the file are :\n\n{content[:300]}")
# Out:
# length of content: 5803
# The estimated tokens are:1450
# first 300 characters of the file are :
#
# Web Scraping: Concepts, Tools, and Real-World Use Cases
#
# Web scraping is the process of automatically extracting data from websites. Instead of manually copying information from web pages, scraping allows developers to collect large amounts of data quickly using scripts or programs. This technique i

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 200
)


chunks = splitter.split_documents(txt_file)

print(f"length of the document:{len(txt_file)}")
print(f"chunk size is:{len(chunks)}")
# Out:
# length of the document:1
# chunk size is:7

# %%
#Go through each chunk and verify overlapping etc.
for index,chunk in enumerate(chunks[:3]):
    print(f"length of chunk {index+1} :{len(chunk.page_content)}")
# Out:
# length of chunk 1 :854
# length of chunk 2 :984
# length of chunk 3 :976
